# %% [markdown]
# Significado das abreviações
#
# fonte de dados - https://www.kaggle.com/datasets/vivovinco/nba-player-stats
#                - https://www.youtube.com/watch?v=9m4n2xVzk9o
#
# Rk : Rank
# Player : Player's name
# Pos : Position
# Age : Player's age
# Tm : Team
# G : Games played
# GS : Games started
# MP : Minutes played per game
# FG : Field goals per game
# FGA : Field goal attempts per game
# FG% : Field goal percentage
# 3P : 3-point field goals per game
# 3PA : 3-point field goal attempts per game
# 3P% : 3-point field goal percentage
# 2P : 2-point field goals per game
# 2PA : 2-point field goal attempts per game
# 2P% : 2-point field goal percentage
# eFG% : Effective field goal percentage
# FT : Free throws per game
# FTA : Free throw attempts per game
# FT% : Free throw percentage
# ORB : Offensive rebounds per game
# DRB : Defensive rebounds per game
# TRB : Total rebounds per game
# AST : Assists per game
# STL : Steals per game
# BLK : Blocks per game
# TOV : Turnovers per game
# PF : Personal fouls per game
# PTS : Points per game

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sn
import io

# %%
df = pd.read_csv(r"C:\Users\s145n\Documents\Mdoc\D.A\nba_stats\vinteum_vintedois_ jodagores_regular.csv",sep=";") 
df.head
# Out:
# <bound method NDFrame.head of       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=812, step=1)

# %%
df.describe()
# Out:
#                Rk         Age           G          GS          MP          FG  \
# count  812.000000  812.000000  812.000000  812.000000  812.000000  812.000000
# mean   304.501232   26.051724   36.704433   16.672414   18.265394    2.869951
# std    172.637333    4.059640   25.899099   23.817195    9.648292    2.223988
# min      1.000000   19.000000    1.000000    0.000000    1.000000    0.000000
# 25%    158.750000   23.000000   12.000000    0.000000   10.500000    1.200000
# 50%    300.500000   25.000000   36.500000    4.000000   17.500000    2.400000
# 75%    459.000000   29.000000   61.000000   25.000000   25.725000    3.900000
# max    605.000000   41.000000   82.000000   82.000000   43.500000   11.400000
#
#               FGA         FG%          3P         3PA  ...         FT%  \
# count  812.000000  812.000000  812.000000  812.000000  ...  812.000000
# mean     6.386576    0.426235    0.871305    2.560591  ...    0.658267
# ...

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.dtypes
# Out:
# Rk          int64
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=812, step=1)

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.T
# Out:
#                      0             1            2             3    \
# Rk                     1             2            3             4
# Player  Precious Achiuwa  Steven Adams  Bam Adebayo  Santi Aldama
# Pos                    C             C            C            PF
# Age                   22            28           24            21
# Tm                   TOR           MEM          MIA           MEM
# G                     73            76           56            32
# GS                    28            75           56             0
# MP                  23.6          26.3         32.6          11.3
# FG                   3.6           2.8          7.3           1.7
# FGA                  8.3           5.1         13.0           4.1
# FG%                0.439         0.547        0.557         0.402
# 3P                   0.8           0.0          0.0           0.2
# 3PA                  2.1           0.0          0.1           1.5
# ...

# %%
df.isnull().sum() # procura valores nulos
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
df = df.fillna(0) #preenchendo esses valores nulos com zero

# %% [markdown]
# #Qual jogador marcou mais pontos por jogo?

# %%
df.PTS #imprimiu os dados da linha pontos(PTS)
# Out:
# 0       9.1
# 1       6.9
# 2      19.1
# 3       4.1
# 4      12.9
#        ...
# 807     6.3
# 808    28.4
# 809     5.3
# 810     5.2
# 811    10.3
# Name: PTS, Length: 812, dtype: float64

# %%
df.PTS.max() # imprime o número máximo de pontos
# Out:
# 30.6

# %% [markdown]
# #Qual jogador marcou essa pontuação?

# %%
df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df[df.PTS == df.PTS.max()]
# Out:
#       Rk       Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  ORB  \
# 206  162  Joel Embiid   C   27  PHI  68  68  33.8  9.8  19.6  ...  0.814  2.1
#
#      DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 206  9.6  11.7  4.2  1.1  1.5  3.1  2.7  30.6
#
# [1 rows x 30 columns]

# %% [markdown]
# ###De acordo com os dados o jogador que mais pontou foi ,Joel Embiid. Jogando pelo Philadelphia 76ers , na posição de pivo/center(C).

# %%
PlayerMaxPoints = df[df.PTS == df.PTS.max()]  ##mostra o time em que Joel Embiid jogava quando atingiu a marca.
PlayerMaxPoints.Tm
# Out:
# 206    PHI
# Name: Tm, dtype: object

# %% [markdown]
# #Em qual posição o jogador atua?

# %%
PlayerMaxPoints.Pos
# Out:
# 206    C
# Name: Pos, dtype: object

# %% [markdown]
# #Quantos jogos o atleta realizou na temporada?

# %%
PlayerMaxPoints.G  # O atleta realizou 68 jogos na temporada
# Out:
# 206    68
# Name: G, dtype: int64

# %% [markdown]
# #qual jogador marcou mais de 25 pontos por jogo?

# %%
df[df.PTS > 25]
# Out:
#       Rk                 Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 15    12  Giannis Antetokounmpo  PF   27  MIL  67  67  32.9  10.3  18.6  ...
# 70    59           Devin Booker  SG   25  PHO  68  68  34.5   9.7  20.9  ...
# 159  126          Stephen Curry  PG   33  GSW  64  64  34.5   8.4  19.1  ...
# 167  134          DeMar DeRozan  PF   32  CHI  76  76  36.1  10.2  20.2  ...
# 178  141            Luka Don?i?  PG   22  DAL  65  65  35.4   9.9  21.6  ...
# 198  154           Kevin Durant  PF   33  BRK  55  55  37.2  10.5  20.3  ...
# 206  162            Joel Embiid   C   27  PHI  68  68  33.8   9.8  19.6  ...
# 356  266           Kyrie Irving  PG   29  BRK  29  29  37.6  10.0  21.2  ...
# 368  274           LeBron James  SF   37  LAL  56  56  37.2  11.4  21.8  ...
# 391  290           Nikola Joki?   C   26  DEN  74  74  33.5  10.3  17.7  ...
# 515  383       Donovan Mitchell  SG   25  UTA  67  67  33.8   9.2  20.5  ...
# ...

# %% [markdown]
# #Qual jogador acertou mais cestas de três pontos por jogo?

# %%
df[df['3P'] == df['3P'].max()]
# Out:
#       Rk         Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 159  126  Stephen Curry  PG   33  GSW  64  64  34.5  8.4  19.1  ...  0.923
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 159  0.5  4.7  5.2  6.3  1.3  0.4  3.2  2.0  25.5
#
# [1 rows x 30 columns]

# %% [markdown]
# #Qual jogador tem mais assistências por jogo?

# %%
df[df['AST'] == df['AST'].max()]
# Out:
#       Rk      Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  ORB  \
# 582  438  Chris Paul  PG   36  PHO  65  65  32.9  5.6  11.3  ...  0.837  0.3
#
#      DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 582  4.0  4.4  10.8  1.9  0.3  2.4  2.1  14.7
#
# [1 rows x 30 columns]

# %% [markdown]
# #Que jogador marcou o maior número de pontos(PTS) atuando no Los Angeles Lakers?

# %%
LAL = df.groupby('Tm').get_group('LAL') # dentro do grupo time(Tm) foi selecionado o Losangeles Lakers

# %%
LAL
# Out:
#       Rk               Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 17    14      Carmelo Anthony  PF   37  LAL  69   3  26.0   4.6  10.5  ...
# 21    18         Trevor Ariza  SF   36  LAL  24  11  19.3   1.4   4.1  ...
# 24    19        D.J. Augustin  PG   34  LAL  21   0  17.8   1.9   4.1  ...
# 46    39        Kent Bazemore  SF   32  LAL  39  14  14.0   1.2   3.6  ...
# 74    63        Avery Bradley  SG   31  LAL  62  45  22.7   2.4   5.6  ...
# 90    74   Chaundee Brown Jr.  SF   23  LAL   2   0  10.5   0.5   3.5  ...
# 137  112      Darren Collison  PG   34  LAL   3   0  12.3   0.7   2.3  ...
# 160  127        Anthony Davis   C   28  LAL  40  40  35.1   9.3  17.4  ...
# 183  146      Sekou Doumbouya  PF   21  LAL   2   0   8.0   2.5   4.0  ...
# 205  161      Wayne Ellington  SG   34  LAL  43   9  18.8   2.3   5.5  ...
# 240  180       Wenyen Gabriel  PF   24  LAL  19   5  16.4   2.6   5.1  ...
# ...

# %%
LAL[LAL.PTS == LAL.PTS.max()] # dentro do grupo LAL foi selecionado o jogador que mais pontuou
# Out:
#       Rk        Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...    FT%  \
# 368  274  LeBron James  SF   37  LAL  56  56  37.2  11.4  21.8  ...  0.756
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 368  1.1  7.1  8.2  6.2  1.3  1.1  3.5  2.2  30.3
#
# [1 rows x 30 columns]

# %% [markdown]
# #Das 5 posções , qual delas marcou mais pontos?

# %%
df.groupby('Pos').PTS.describe() ## Agrupa-se os jogadores por posição em que atuam.
# Out:
#        count       mean       std   min     25%    50%     75%   max
# Pos
# C      130.0   7.690769  5.621146   0.0   3.775   6.95   9.550  30.6
# C-PF     2.0  12.850000  8.555992   6.8   9.825  12.85  15.875  18.9
# PF     152.0   7.737500  6.036498   0.0   3.300   6.50  10.150  29.9
# PF-SF    1.0   8.500000       NaN   8.5   8.500   8.50   8.500   8.5
# PG     155.0   8.325161  6.693276   0.0   3.300   6.30  11.550  28.4
# PG-SG    1.0  22.000000       NaN  22.0  22.000  22.00  22.000  22.0
# SF     158.0   7.270253  6.195494   0.0   3.000   5.80   9.675  30.3
# SF-SG    5.0   8.660000  6.429852   3.1   3.800   7.30  10.100  19.0
# SG     199.0   7.810553  6.059656   0.0   2.950   6.20  11.250  26.8
# SG-PG    4.0   9.525000  5.701681   4.0   4.975   9.40  13.950  15.3
# SG-SF    5.0   7.360000  4.635515   3.5   3.900   6.20   8.300  14.9

# %% [markdown]
# #Serão mostradas as 5 posições mais comuns

# %%
positions = ['C','PF','SF','PG','SG']
POS = df[ df['Pos'].isin(positions)  ]
POS
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
POS.groupby('Pos').PTS.describe()
# Out:
#      count      mean       std  min    25%   50%     75%   max
# Pos
# C    130.0  7.690769  5.621146  0.0  3.775  6.95   9.550  30.6
# PF   152.0  7.737500  6.036498  0.0  3.300  6.50  10.150  29.9
# PG   155.0  8.325161  6.693276  0.0  3.300  6.30  11.550  28.4
# SF   158.0  7.270253  6.195494  0.0  3.000  5.80   9.675  30.3
# SG   199.0  7.810553  6.059656  0.0  2.950  6.20  11.250  26.8

# %% [markdown]
# #Cria-se um dataframe , para que fique mais clara a plotagem em alguns histogramas. O dataframe contém os dados de posse de bola e de pontuação.

# %%
PTS = df[['Pos','PTS']]

positions = ['C','PF','SF','PG','SG']
PTS = PTS[ PTS['Pos'].isin(positions) ]

PTS
# Out:
#     Pos   PTS
# 0     C   9.1
# 1     C   6.9
# 2     C  19.1
# 3    PF   4.1
# 4     C  12.9
# ..   ..   ...
# 807  PF   6.3
# 808  PG  28.4
# 809   C   5.3
# 810   C   5.2
# 811   C  10.3
#
# [794 rows x 2 columns]

# %%
PTS['PTS'].hist(by=PTS['Pos']) # Mostra um histograma para cada posição.
# Out:
# array([[<AxesSubplot:title={'center':'C'}>,
#         <AxesSubplot:title={'center':'PF'}>],
#        [<AxesSubplot:title={'center':'PG'}>,
#         <AxesSubplot:title={'center':'SF'}>],
#        [<AxesSubplot:title={'center':'SG'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
PTS['PTS'].hist(by=PTS['Pos'], layout=(1,5))
# Out:
# array([<AxesSubplot:title={'center':'C'}>,
#        <AxesSubplot:title={'center':'PF'}>,
#        <AxesSubplot:title={'center':'PG'}>,
#        <AxesSubplot:title={'center':'SF'}>,
#        <AxesSubplot:title={'center':'SG'}>], dtype=object)

# %%
PTS['PTS'].hist(by=PTS['Pos'], layout=(1,5), figsize=(16,2))
# Out:
# array([<AxesSubplot:title={'center':'C'}>,
#        <AxesSubplot:title={'center':'PF'}>,
#        <AxesSubplot:title={'center':'PG'}>,
#        <AxesSubplot:title={'center':'SF'}>,
#        <AxesSubplot:title={'center':'SG'}>], dtype=object)

# %%
#Utilizando Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(PTS, col="Pos")
g.map(plt.hist, "PTS");

# %% [markdown]
# #BoxPlot

# %%
PTS.boxplot(column='PTS', by='Pos')
# Out:
# <AxesSubplot:title={'center':'PTS'}, xlabel='Pos'>

# %% [markdown]
# #Heat map

# %%
corr = df.corr() #Computando a matriz de correlação(Utilizando o coeficiente de correlação de Pearson)
corr
# Out:
#             Rk       Age         G        GS        MP        FG       FGA  \
# Rk    1.000000 -0.037216 -0.066503 -0.086550 -0.050971 -0.057393 -0.054080
# Age  -0.037216  1.000000  0.042212  0.052232  0.145388  0.087947  0.085564
# G    -0.066503  0.042212  1.000000  0.680436  0.620290  0.563977  0.542432
# GS   -0.086550  0.052232  0.680436  1.000000  0.751435  0.736394  0.713715
# MP   -0.050971  0.145388  0.620290  0.751435  1.000000  0.886895  0.898603
# FG   -0.057393  0.087947  0.563977  0.736394  0.886895  1.000000  0.970853
# FGA  -0.054080  0.085564  0.542432  0.713715  0.898603  0.970853  1.000000
# FG%  -0.001554  0.059665  0.311718  0.226771  0.299632  0.355639  0.211332
# 3P   -0.052654  0.121144  0.475981  0.530903  0.720450  0.679117  0.764839
# 3PA  -0.052840  0.104885  0.457740  0.524531  0.732635  0.680076  0.794470
# 3P%   0.016625  0.084448  0.372137  0.226564  0.417982  0.352440  0.367820
# ...

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Gráfico de dispersão

# %%
df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
# Selecionaremos as colunas que tenham dados númericos

# %%
df.select_dtypes(include=['number'])
# Out:
#       Rk  Age   G  GS    MP   FG   FGA    FG%   3P  3PA  ...    FT%  ORB  DRB  \
# 0      1   22  73  28  23.6  3.6   8.3  0.439  0.8  2.1  ...  0.595  2.0  4.5
# 1      2   28  76  75  26.3  2.8   5.1  0.547  0.0  0.0  ...  0.543  4.6  5.4
# 2      3   24  56  56  32.6  7.3  13.0  0.557  0.0  0.1  ...  0.753  2.4  7.6
# 3      4   21  32   0  11.3  1.7   4.1  0.402  0.2  1.5  ...  0.625  1.0  1.7
# 4      5   36  47  12  22.3  5.4   9.7  0.550  0.3  1.0  ...  0.873  1.6  3.9
# ..   ...  ...  ..  ..   ...  ...   ...    ...  ...  ...  ...    ...  ...  ...
# 807  601   33  26   0  18.3  2.6   5.5  0.465  0.7  1.7  ...  0.481  1.5  2.9
# 808  602   23  76  76  34.9  9.4  20.3  0.460  3.1  8.0  ...  0.904  0.7  3.1
# 809  603   23  56  12  12.6  2.3   4.4  0.526  0.0  0.2  ...  0.623  1.5  3.7
# 810  604   29  27   0  13.1  1.9   3.3  0.567  0.0  0.1  ...  0.776  1.9  2.8
# 811  605   24  76  76  24.4  4.1   6.5  0.626  0.0  0.0  ...  0.727  2.9  5.6
#
# ...

# %% [markdown]
# #Select the first 5 columns (indexando number(numeros))

# %%
number = df.select_dtypes(include=['number'])

# %%
number.iloc[:,:5]
# Out:
#       Rk  Age   G  GS    MP
# 0      1   22  73  28  23.6
# 1      2   28  76  75  26.3
# 2      3   24  56  56  32.6
# 3      4   21  32   0  11.3
# 4      5   36  47  12  22.3
# ..   ...  ...  ..  ..   ...
# 807  601   33  26   0  18.3
# 808  602   23  76  76  34.9
# 809  603   23  56  12  12.6
# 810  604   29  27   0  13.1
# 811  605   24  76  76  24.4
#
# [812 rows x 5 columns]

# %% [markdown]
# #Selecionaremos 5 colunas especificas pelo nome da coluna

# %%
selections = ['Age','G','STL','BLK','AST','PTS']
dfs = df[selections]
dfs
# Out:
#      Age   G  STL  BLK  AST   PTS
# 0     22  73  0.5  0.6  1.1   9.1
# 1     28  76  0.9  0.8  3.4   6.9
# 2     24  56  1.4  0.8  3.4  19.1
# 3     21  32  0.2  0.3  0.7   4.1
# 4     36  47  0.3  1.0  0.9  12.9
# ..   ...  ..  ...  ...  ...   ...
# 807   33  26  1.2  0.4  1.7   6.3
# 808   23  76  0.9  0.1  9.7  28.4
# 809   23  56  0.3  0.4  0.9   5.3
# 810   29  27  0.3  0.2  0.8   5.2
# 811   24  76  0.5  1.0  1.6  10.3
#
# [812 rows x 6 columns]
